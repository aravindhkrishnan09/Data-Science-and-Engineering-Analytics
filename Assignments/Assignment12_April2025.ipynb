# %% [markdown]
# # Mapping

# %%
#mapping
import pandas as pd

a = {'name': ['John', 'Jane', 'Jim', 'Jack'], 'profession': ['doctor', 'engineer', 'teacher', 'artist']}
df = pd.DataFrame(a)
df['profession_code'] = df['profession'].map({'doctor': 1, 'engineer': 2, 'teacher': 3, 'artist': 4})
print(df)
# Out:
#    name profession  profession_code
# 0  John     doctor                1
# 1  Jane   engineer                2
# 2   Jim    teacher                3
# 3  Jack     artist                4

# %% [markdown]
# # Apply

# %%
import numpy as np
import pandas as pd

a = np.random.randint(1, 100,5)
a_apply = pd.Series(a).apply(lambda x: x**2)
#using list comprehension
b_apply = pd.Series([x**2 for x in a])
print(a)
print(a_apply)
print(b_apply)
# Out:
# [94 11 12 26 95]
# 0    8836
# 1     121
# 2     144
# 3     676
# 4    9025
# dtype: int64
# 0    8836
# 1     121
# 2     144
# 3     676
# 4    9025
# dtype: int32

# %% [markdown]
# # Eval function

# %%
#evaluate
import pandas as pd
import numpy as np
a = np.random.randint(1, 100, 5)
a_eval = pd.Series(a).apply(lambda x: eval('x**2'))
#using list comprehension
b_eval = pd.Series([eval('x**2') for x in a])
print(a)
# Out:
# [95 96 71 51 25]

# %% [markdown]
# #3d plot

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z)
